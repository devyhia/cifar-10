# %% [markdown]
# ### Paper Preparation

# %%
from init import *

# %%
# %matplotlib inline

# %%
pca_200 = pyload("pickles/pca_200.pickle")

# %%
pca_200.explained_variance_ratio_[-10:].sum()
# Out:
# 0.0028429927392297953

# %%
plt.imshow(pca_200.components_[190].reshape(3,32,32).transpose(1,2,0))

# %%
pca_200.explained_variance_ratio_[:150].sum()
# Out:
# 0.92890828995565111

# %%
surf = np.loadtxt("pickles/SURFfeatures.txt")

# %%
surf.shape
# Out:
# (50000, 1500)

# %%
pydump(surf, "pickles/surf.pickle")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

clf_log = LogisticRegression()
clf_log.fit(surf,)
